# %%
# %pip install --upgrade nbformat
# %pip install ipykernel
# %pip install dash
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: nbformat in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbformat) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=2.6->nbformat) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=2.6->nbformat) (0.23.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (308)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.12.2)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\alexc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: ipykernel in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (6.29.5)
# Requirement already satisfied: comm>=0.1.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel) (1.8.12)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel) (8.32.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel) (24.2)
# Requirement already satisfied: psutil in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (308)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\alexc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: dash in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.18.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dash) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dash) (6.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dash) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from dash) (65.5.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly>=5.0.0->dash) (1.28.0)
# Requirement already satisfied: packaging in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly>=5.0.0->dash) (24.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->dash) (2025.1.31)
# Requirement already satisfied: six>=1.7.0 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from retrying->dash) (1.17.0)
# Requirement already satisfied: colorama in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click>=8.1.3->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\alexc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# # Apartado 1
#
# En este primer apartado, comenzarás preparando el entorno de trabajo importando las librerías necesarias para la actividad. Utilizaremos las siguientes librerías en el orden indicado a lo largo de la actividad:
#
#     1.1 NumPy: Para trabajar con arreglos numéricos y realizar cálculos eficientes.
#
#     1.2 Matplotlib: Para la creación de gráficos estáticos.
#
#     1.3 Seaborn: Para generar visualizaciones más estilizadas y analíticas.
#
#     1.4 Plotly: Para gráficos interactivos avanzados.
#
# Configura Matplotlib para que las gráficas se muestren en el notebook con %matplotlib inline.
#
# Establece un estilo de Seaborn con sns.set_style(). Puedes elegir entre 'whitegrid', 'darkgrid', 'white', 'dark' o 'ticks'.

# %%
# Importar las librerías necesarias
# %pip install pandas matplotlib seaborn numpy matplotlib plotly

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.express as px
from plotly.offline import init_notebook_mode

init_notebook_mode(connected=True)  # Habilitar la renderización interactiva en Jupyter


# Configuración para que las gráficas de Matplotlib se muestren en el notebook
# %matplotlib inline

# Establecer el estilo de Seaborn
sns.set_style('darkgrid')  # Puedes cambiar 'whitegrid' por 'darkgrid', 'white', 'dark' o 'ticks' si prefieres otro estilo
# Out:
# Requirement already satisfied: pandas in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.10.0)
# Requirement already satisfied: seaborn in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.13.2)
# Requirement already satisfied: numpy in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.3)
# Requirement already satisfied: plotly in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (6.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly) (1.28.0)
# Requirement already satisfied: six>=1.5 in c:\users\alexc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\alexc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>

# %% [markdown]
# # Apartado 2
#
# En este apartado, se cargarán los dos datasets en DataFrames utilizando la librería pandas. Posteriormente, se realizará una exploración inicial de los datos para comprender su estructura, revisar si hay valores nulos y verificar sus características generales.
#
#     Los datasets que vamos a utilizar son:
#
# Precio_Vida.csv: Contiene información sobre el costo de vida en diferentes regiones o países.
#
# Renta_por_hogar.csv: Contiene información sobre los ingresos medios por hogar en distintas regiones o países.
#
#     Objetivos de este apartado:
#
# Cargar los archivos CSV en DataFrames.
#
# Visualizar las primeras filas de cada conjunto de datos.
#
# Identificar valores nulos y el tipo de datos en cada columna.

# %%
# Importamos la librería pandas
import pandas as pd

# Cargamos los datasets en DataFrames
precio_vida_df = pd.read_csv('Precio_Vida.csv')
renta_hogar_df = pd.read_csv('Renta_por_hogar.csv')

# Visualizamos las primeras filas de cada conjunto de datos
print("Primeras filas del dataset Precio_Vida:")
print(precio_vida_df.head())

print("\nPrimeras filas del dataset Renta_por_hogar:")
print(renta_hogar_df.head())

# Identificamos valores nulos y el tipo de datos en cada columna
print("\nInformación sobre el dataset Precio_Vida:")
print(precio_vida_df.info())

print("\nInformación sobre el dataset Renta_por_hogar:")
print(renta_hogar_df.info())
# Out:
# Primeras filas del dataset Precio_Vida:
#   ;"Índice general - Índice";"Alimentos y bebidas no alcohólicas - Índice";"Bebidas alcohólicas y tabaco - Índice";"Vestido y calzado - Índice";"Vivienda  \
# 0  2008;"86.844";"87.049";"62.186";"98.448";"76.3...
# 1  2009;"85.873";"85.245";"67.313";"96.924";"77.8...
# 2  2010;"87.157";"84.426";"76.079";"96.949";"79.8...
# 3  2011;"90.212";"85.860";"78.949";"97.439";"86.7...
# 4  2012;"91.947";"87.314";"88.149";"97.811";"90.8...
#
#     agua   electricidad   gas y otros combustibles - Índice";"Muebles  \
# 0    NaN            NaN                                           NaN
# 1    NaN            NaN                                           NaN
# 2    NaN            NaN                                           NaN
# 3    NaN            NaN                                           NaN
# 4    NaN            NaN                                           NaN
#
#     artículos del hogar y artículos para el mantenimiento corriente del hogar - Índice";"Sanidad - Índice";"Transporte - Índice";"Comunicaciones - Índice";"Ocio y cultura - Índice";"Enseñanza - Índice";"Restaurantes y hoteles - Índice";"Otros bienes y servicios - Índice"
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# Primeras filas del dataset Renta_por_hogar:
#   ;"Cantabria - Renta neta media por persona - Valor"
# 0                                       2008;"11232"
# 1                                       2009;"12184"
# 2                                       2010;"11083"
# 3                                       2011;"10495"
# 4                                       2012;"10388"
#
# Información sobre el dataset Precio_Vida:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 5 columns):
#  #   Column                                                                                                                                                                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                        --------------  -----
#  0   ;"Índice general - Índice";"Alimentos y bebidas no alcohólicas - Índice";"Bebidas alcohólicas y tabaco - Índice";"Vestido y calzado - Índice";"Vivienda                                                                                                                       17 non-null     object
#  1    agua                                                                                                                                                                                                                                                                         0 non-null      float64
#  2    electricidad                                                                                                                                                                                                                                                                 0 non-null      float64
#  3    gas y otros combustibles - Índice";"Muebles                                                                                                                                                                                                                                  0 non-null      float64
#  4    artículos del hogar y artículos para el mantenimiento corriente del hogar - Índice";"Sanidad - Índice";"Transporte - Índice";"Comunicaciones - Índice";"Ocio y cultura - Índice";"Enseñanza - Índice";"Restaurantes y hoteles - Índice";"Otros bienes y servicios - Índice"  0 non-null      float64
# dtypes: float64(4), object(1)
# memory usage: 812.0+ bytes
# None
#
# Información sobre el dataset Renta_por_hogar:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 1 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   ;"Cantabria - Renta neta media por persona - Valor"  17 non-null     object
# dtypes: object(1)
# memory usage: 268.0+ bytes
# None

# %% [markdown]
# # Apartado 3
#
# Tras la exploración inicial de los datasets, se han identificado algunos problemas en su formato que requieren ser corregidos antes de proceder con el análisis y visualización de datos.
#
#     Problemas detectados:
#
# Separadores incorrectos: Los archivos CSV parecen estar delimitados por ; en lugar de ,, lo que ha provocado que las columnas no se separen correctamente.
#
# Nombres de columnas mal formateados: Los nombres de las columnas contienen caracteres especiales y descripciones largas que dificultan su uso.
#
# Valores nulos: Existen múltiples columnas con valores completamente nulos, lo que sugiere que deben eliminarse o corregirse.
#
#     Objetivo de este apartado
#
# Reimportar los archivos utilizando ; como delimitador.
#
# Renombrar las columnas con nombres más comprensibles.
#
# Eliminar columnas innecesarias o completamente vacías.

# %%
import pandas as pd

# 
precio_vida_df = pd.read_csv('Precio_Vida.csv', sep=';')  
renta_hogar_df = pd.read_csv('Renta_por_hogar.csv', sep=';')  


# 
precio_vida_df.columns = ['Anio', 'Indice_General', 'Alimentos_y_Bebidas', 'Bebidas_Alcoolicas_y_Tabaco', 
                          'Vestido_y_Calzado', 'Vivienda_y_Energía', 'Muebles_y_Hogar', 'Sanidad', 'Transporte', 
                          'Comunicaciones', 'Ocio_y_Cultura', 'Enseñanza', 'Restaurantes_y_Hoteles', 'Otros_Bienes_y_Servicios']

renta_hogar_df.columns = ['Anio', 'Renta_Media_Cantabria']


# 
precio_vida_df = precio_vida_df.dropna(axis=1, how='all')
renta_hogar_df = renta_hogar_df.dropna(axis=1, how='all')

# 
print("Primeras filas del dataset Precio_Vida después de la limpieza:")
print(precio_vida_df.head())

print("\nPrimeras filas del dataset Renta_por_hogar después de la limpieza:")
print(renta_hogar_df.head())

# 
print("\nInformación sobre el dataset Precio_Vida después de la limpieza:")
print(precio_vida_df.info())

print("\nInformación sobre el dataset Renta_por_hogar después de la limpieza:")
print(renta_hogar_df.info())
# Out:
# Primeras filas del dataset Precio_Vida después de la limpieza:
#    Anio  Indice_General  Alimentos_y_Bebidas  Bebidas_Alcoolicas_y_Tabaco  \
# 0  2008          86.844               87.049                       62.186
# 1  2009          85.873               85.245                       67.313
# 2  2010          87.157               84.426                       76.079
# 3  2011          90.212               85.860                       78.949
# 4  2012          91.947               87.314                       88.149
#
#    Vestido_y_Calzado  Vivienda_y_Energía  Muebles_y_Hogar  Sanidad  \
# 0             98.448              76.372           94.781   85.065
# 1             96.924              77.861           97.172   83.507
# 2             96.949              79.815           96.310   83.406
# 3             97.439              86.710           98.433   83.453
# 4             97.811              90.812           96.822   80.906
#
#    Transporte  Comunicaciones  Ocio_y_Cultura  Enseñanza  \
# 0      87.475         114.238         102.593     79.248
# 1      78.690         113.615         103.851     81.833
# 2      83.502         112.480         102.817     84.053
# 3      90.696         112.897         102.620     85.266
# 4      94.334         108.503         103.559     86.760
#
#    Restaurantes_y_Hoteles  Otros_Bienes_y_Servicios
# 0                  85.110                    80.530
# 1                  86.445                    82.291
# 2                  87.156                    83.947
# 3                  89.420                    86.372
# 4                  90.544                    87.842
#
# Primeras filas del dataset Renta_por_hogar después de la limpieza:
#    Anio  Renta_Media_Cantabria
# 0  2008                  11232
# 1  2009                  12184
# 2  2010                  11083
# 3  2011                  10495
# 4  2012                  10388
#
# Información sobre el dataset Precio_Vida después de la limpieza:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Anio                         17 non-null     int64
#  1   Indice_General               17 non-null     float64
#  2   Alimentos_y_Bebidas          17 non-null     float64
#  3   Bebidas_Alcoolicas_y_Tabaco  17 non-null     float64
#  4   Vestido_y_Calzado            17 non-null     float64
#  5   Vivienda_y_Energía           17 non-null     float64
#  6   Muebles_y_Hogar              17 non-null     float64
#  7   Sanidad                      17 non-null     float64
#  8   Transporte                   17 non-null     float64
#  9   Comunicaciones               17 non-null     float64
#  10  Ocio_y_Cultura               17 non-null     float64
#  11  Enseñanza                    17 non-null     float64
#  12  Restaurantes_y_Hoteles       17 non-null     float64
#  13  Otros_Bienes_y_Servicios     17 non-null     float64
# dtypes: float64(13), int64(1)
# memory usage: 2.0 KB
# None
#
# Información sobre el dataset Renta_por_hogar después de la limpieza:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Anio                   17 non-null     int64
#  1   Renta_Media_Cantabria  17 non-null     int64
# dtypes: int64(2)
# memory usage: 404.0 bytes
# None

# %% [markdown]
# # Apartado 4
#
#     En este apartado, representaremos el Índice General del dataset Precio de Vida utilizando Matplotlib en un gráfico combinado que incluya:
#
# Un gráfico de barras para visualizar los valores del índice a lo largo de los años.
#
# Una línea superpuesta en otro color para destacar la tendencia del índice.
#
#     Objetivos de este apartado:
#
# Extraer la columna correspondiente al Índice General y los años asociados.
#
# Representar los valores en un gráfico de barras.
#
# Superponer una línea de tendencia sobre el gráfico.
#
# Personalizar la gráfica con títulos, etiquetas y colores diferenciados.

# %%
import matplotlib.pyplot as plt
import numpy as np


# Datos de ejemplo (sustituir con tu DataFrame real)
años = precio_vida_df['Anio'].values  # Convertir a numpy array
indice_general = precio_vida_df['Indice_General'].values  # Convertir a numpy array

# Crear los valores de años comenzando desde 2007.5
años_modificados = np.linspace(2007.5, años[-1], len(años))

# Ajustar los valores del índice general a los nuevos años
# Si es necesario, puedes usar interpolación
indices_modificados = np.interp(años_modificados, años, indice_general)

# Generar la gráfica
plt.figure(figsize=(10, 6))

# Graficar las barras
plt.bar(años_modificados, indices_modificados, color='lightblue', label='Índice General')

# Graficar la línea conectando los puntos
plt.plot(años_modificados, indices_modificados, color='red', marker='o', markersize=6, label='Tendencia')

# Personalización de la gráfica
plt.title('Índice General del Costo de Vida a lo largo de los años', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Índice General', fontsize=12)
plt.xticks(rotation=45)
plt.legend()

# Ajustar el layout y mostrar la gráfica
plt.tight_layout()
plt.show()

# %% [markdown]
# # Apartado 5
#
# En este apartado, se representarán dos gráficos en una misma figura para analizar la evolución de distintos indicadores del costo de vida y la renta por hogar:
#
#     Gráfico de líneas:
#
# Se representará la evolución de los índices de:
#
# Alimentación
#
# Bebidas Alcohólicas
#
# Comunicaciones
#
# Cada línea tendrá un estilo claramente diferenciado.
#
# Se personalizará el fondo y la cuadrícula para mejorar la visualización.
#
#     Gráfico de barras comparativo:
#
# Se comparará el Índice General del Costo de Vida con la Renta por Hogar.
#
# El Índice utilizará el eje Y de la derecha y la Renta el de la izquierda, para aparecer a escala.
#
# Se utilizarán colores oscuros para dar un aspecto profesional y diferenciado.

# %%
# 
años = precio_vida_df["Anio"].astype(int).values
alimentacion = precio_vida_df["Alimentos_y_Bebidas"].values
bebidas_alcoholicas = precio_vida_df["Bebidas_Alcoolicas_y_Tabaco"].values
comunicaciones = precio_vida_df["Comunicaciones"].values
indice_general = precio_vida_df["Indice_General"].values  # 

# 
renta_por_hogar = renta_hogar_df["Renta_Media_Cantabria"].values

# 
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# 
axs[0].plot(años, alimentacion, label='Alimentación', color='#ba98f5', marker='s', linestyle='--', linewidth=2)
axs[0].plot(años, bebidas_alcoholicas, label='Bebidas Alcohólicas', color='#98f5d5', marker='o', linestyle=':', linewidth=2)
axs[0].plot(años, comunicaciones, label='Comunicaciones', color='#f5d698', marker='D', linestyle='-.', linewidth=2)

# 
axs[0].set_title('Evolución de los índices del costo de vida', fontsize=14)
axs[0].set_xlabel('Año', fontsize=12)
axs[0].set_ylabel('Índice', fontsize=12)

# 
axs[0].grid(True, which='both', linestyle='--', linewidth=0.5)
axs[0].set_facecolor('#f5f5f5')  
axs[0].legend()

# 
ax2 = axs[1].twinx()

# 
axs[1].bar(años, indice_general, color='#16a085', alpha=0.7, label='Índice General', width=0.4)

# 
ax2.bar(años, renta_por_hogar, color='#8e44ad', alpha=0.7, label='Renta por Hogar', width=0.4)

# 
axs[1].set_title('Comparación del Índice General con la Renta por Hogar', fontsize=14)
axs[1].set_xlabel('Año', fontsize=12)
axs[1].set_ylabel('Índice General', fontsize=12)
ax2.set_ylabel('Renta por Hogar', fontsize=12)

# 
axs[1].grid(True, which='both', linestyle='--', linewidth=0.5)
axs[1].set_facecolor('#f5f5f5')  
axs[1].legend(loc='upper left')
ax2.legend(loc='upper right')


precio_vida_df["Anio"] = pd.to_numeric(precio_vida_df["Anio"], errors='coerce')

# Verificar los valores únicos de la columna "Anio"
print("Valores únicos en la columna 'Anio':", precio_vida_df["Anio"].unique())
# 
plt.tight_layout()
plt.show()
# Out:
# Valores únicos en la columna 'Anio': [2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021
#  2022 2023 2024]

# %% [markdown]
# # Apartado 6
#
# En este apartado, se representará un gráfico de dispersión (scatter plot) que visualice la diferencia entre los valores de los índices en los años 2008 y 2024.
#
#     Objetivos de este apartado:
#
# Extraer los valores de todos los índices en los años 2008 y 2024.
#
# Calcular la diferencia entre 2024 y 2008 para cada índice.
#
# Representar los cambios en un scatter plot con etiquetas para cada índice.

# %%
# 
precio_vida_df["Anio"] = pd.to_numeric(precio_vida_df["Anio"], errors='coerce')

# 
print("Valores únicos en la columna 'Anio':", precio_vida_df["Anio"].unique())

precio_vida_df.columns = ['Anio','Indice_General', 'Alimentos', 'Bebidas', 
                          'Vestido', 'Vivienda', 'Muebles', 
                          'Sanidad', 'Transporte', 'Comunicaciones', 'Ocio', 
                          'Enseñanza', 'Restaurantes', 'Bienes']

# 
indice_2008 = precio_vida_df[precio_vida_df["Anio"] == 2008]
indice_2024 = precio_vida_df[precio_vida_df["Anio"] == 2024]

#
indices = ['Indice_General', 'Alimentos', 'Bebidas', 
           'Vestido', 'Vivienda', 'Muebles', 
           'Sanidad', 'Transporte', 'Comunicaciones', 'Ocio', 
           'Enseñanza', 'Restaurantes', 'Bienes']

#
indice_2008 = indice_2008.dropna(subset=indices)
indice_2024 = indice_2024.dropna(subset=indices)

#
diferencias = []
for indice in indices:
    if indice in indice_2008.columns and indice in indice_2024.columns:
        diferencia = indice_2024[indice].values[0] - indice_2008[indice].values[0]
        diferencias.append(diferencia)
    else:
        diferencias.append(np.nan)

#
indices_filtrados = [indices[i] for i in range(len(diferencias)) if not np.isnan(diferencias[i])]
diferencias_filtradas = [d for d in diferencias if not np.isnan(d)]

#
plt.figure(figsize=(10, 6))
plt.scatter(indices_filtrados, diferencias_filtradas, color='#8e44ad', s=100, edgecolor='black')

#
for i, indice in enumerate(indices_filtrados):
    plt.annotate(indice, (indices_filtrados[i], diferencias_filtradas[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=9, rotation=45)

#
plt.axhline(0, color='black', linewidth=1, linestyle='--')

#
plt.title('Diferencia en los índices entre 2008 y 2024', fontsize=14)
plt.xlabel('Índice', fontsize=12)
plt.ylabel('Diferencia (2024 - 2008)', fontsize=12)

#
plt.grid(True, linestyle='--', linewidth=0.5)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# Valores únicos en la columna 'Anio': [2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021
#  2022 2023 2024]

# %% [markdown]
# # Apartado 7
#
# En este apartado, se creará un DataFrame a partir del archivo Turismo.csv y se representarán dos gráficos de tarta (pie charts) en una misma figura.
#
#     Objetivos de este apartado:
#
# Cargar el archivo CSV en un DataFrame.
#
# Extraer los datos correspondientes a los años 1999 y 2024.
#
# Representar los porcentajes de turistas españoles y extranjeros en dos gráficos de tarta.
#
# Aplicar efecto "explode" para resaltar a los turistas españoles.

# %%
# Apartado 7: Gráficos de tarta sobre turismo adaptado al CSV
try:
    turismo_df = pd.read_csv('Turismo.csv', sep=';', dtype={'Año': int})
    
    # Filtrar datos de los años 1999 y 2024
    turismo_1999 = turismo_df[turismo_df['Año'] == 1999]
    turismo_2024 = turismo_df[turismo_df['Año'] == 2024]
    
    # Datos
    labels = ['Españoles', 'Extranjeros']
    sizes_1999 = [turismo_1999['Residentes_España'].values[0], turismo_1999['Residentes_Extranjero'].values[0]]
    sizes_2024 = [turismo_2024['Residentes_España'].values[0], turismo_2024['Residentes_Extranjero'].values[0]]
    
    # Gráficos de tarta
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))
    axs[0].pie(sizes_1999, labels=labels, autopct='%1.1f%%', explode=(0.1, 0), colors=['lightblue', 'orange'])
    axs[0].set_title('Distribución de turistas (1999)')
    
    axs[1].pie(sizes_2024, labels=labels, autopct='%1.1f%%', explode=(0.1, 0), colors=['lightblue', 'orange'])
    axs[1].set_title('Distribución de turistas (2024)')
    
    plt.show()
except Exception as e:
    print(f"Error al cargar los datos: {e}")

# %% [markdown]
# # Apartado 8
#
#     En este apartado, utilizaremos el dataset Titanic incluido en Seaborn para realizar una visualización de datos.
#
# Carga de datos: Importaremos el dataset directamente desde Seaborn.
#
# Visualización: Crearemos un gráfico de dispersión (scatter plot) usando relplot para comparar la edad de los pasajeros con la tarifa de su boleto.
#
# Se utilizará el género como parámetro de color (hue).
#
# Se ajustará el tamaño de los puntos (size) según la clase del pasajero.
#
#     El dataset "titanic" de Seaborn tiene las siguientes columnas principales:
#
# survived (0 = no, 1 = sí)
#
# pclass (1, 2, 3 - Clase del pasajero)
#
# sex (male, female)
#
# age (Edad)
#
# sibsp (Número de hermanos/esposos a bordo)
#
# parch (Número de padres/hijos a bordo)
#
# fare (Tarifa del boleto)
#
# embarked (Puerto de embarque: C, Q, S)
#
# class (First, Second, Third - versión categórica de pclass)
#
# who (man, woman, child - basado en edad y género)
#
# deck (Cubierta del barco, si está disponible)
#
# embark_town (Nombre del puerto de embarque)
#
# alive (yes/no - versión categórica de survived)
#
# alone (Si viajó solo: True/False)

# %%
# Apartado 8: Scatter plot de edad vs tarifa en el Titanic
try:
    titanic_df = sns.load_dataset('titanic')
    
    # Definir colores personalizados
    palette = {"male": "#e75957", "female": "#41acbd"}
    
    # Gráfico de dispersión con relplot
    sns.relplot(
        data=titanic_df, x='age', y='fare', hue='sex', size='pclass',
        sizes=(5, 100), aspect=1.5, palette=palette
    )
    plt.title('Relación entre Edad y Tarifa en el Titanic')
    plt.show()
except Exception as e:
    print(f"Error al cargar los datos del Titanic: {e}")

# %% [markdown]
# # Apartado 9
#
# En este apartado, utilizaremos Seaborn para visualizar la distribución de edades de los pasajeros del Titanic mediante un histograma combinado con una curva de densidad (KDE).
#
#
#     Visualización: Crearemos un histograma con sns.histplot, donde:
#
# Se representará la edad de los pasajeros.
#
# Se superpondrá una curva de densidad (KDE) para visualizar la distribución suavizada.
#
# Se aplicará un estilo elegante con seaborn-darkgrid.

# %%
# Apartado 9: Histograma con KDE de edades en el Titanic
try:
    plt.figure(figsize=(12, 8))
    sns.set_style("darkgrid")
    sns.histplot(titanic_df, x='age', kde=True, bins=30, color='royalblue', edgecolor='black', alpha=0.6)
    plt.title('Distribución de Edades en el Titanic', fontsize=14)
    plt.xlabel('Edad', fontsize=12)
    plt.ylabel('Frecuencia', fontsize=12)
    plt.show()
except Exception as e:
    print(f"Error al generar el histograma: {e}")

# %% [markdown]
# # Apartado 10
#
#     En este apartado, utilizaremos Seaborn para analizar la relación entre la tarifa del boleto (fare) y tres variables clave en el dataset Titanic:
#
# Clase del pasajero (pclass) con un gráfico de caja (boxplot).
#
# Supervivencia (survived) con un gráfico de dispersión tipo enjambre (swarmplot).
#
# Puerto de embarque (embark_town) con un gráfico de distribución proporcional (displot) ECDF.
#
#     Carga y visualización de los datos
#
# A continuación, crearemos una figura con tres gráficos distintos dentro de la misma visualización.

# %%
# Apartado 10: Análisis de la relación entre tarifa y variables clave en el Titanic
try:
    titanic_df = sns.load_dataset('titanic')
    
    # Definir colores personalizados
    palette_boxplot = ['#f55353', '#4bc8ed', '#58f076']  # Colores personalizados para boxplot
    palette_swarmplot = {0: '#aa7fdb', 1: '#ea9d3f'}  # Colores personalizados para swarmplot
    palette_ecdf = ['#890cf7', '#146414', '#f70c8c']  # Colores personalizados para ecdfplot
    
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    
    # Boxplot de tarifa según clase con colores personalizados
    sns.boxplot(data=titanic_df, x='pclass', y='fare', ax=axes[0], palette=palette_boxplot)
    axes[0].set_title('Distribución de Tarifa por Clase')
    
    # Swarmplot de tarifa según supervivencia con colores personalizados
    sns.swarmplot(data=titanic_df, x='survived', y='fare', ax=axes[1], hue='survived', palette=palette_swarmplot, legend=False)
    axes[1].set_title('Tarifa por Supervivencia')
    
    # ECDF de tarifa según puerto de embarque con colores personalizados
    sns.ecdfplot(data=titanic_df, x='fare', hue='embark_town', ax=axes[2], palette=palette_ecdf)
    axes[2].set_title('Distribución Proporcional de Tarifa por Puerto de Embarque')
    
    plt.tight_layout()
    plt.show()
except Exception as e:
    print(f"Error en el análisis del Titanic: {e}")
# Out:
# C:\Users\alexc\AppData\Local\Temp\ipykernel_15892\1331340868.py:13: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\alexc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 58.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# C:\Users\alexc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 26.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# C:\Users\alexc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 62.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# C:\Users\alexc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 33.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %% [markdown]
# # ¿Qué conclusiones podemos tomar de los datos del df si observamos la primera gráfica?
# La primera gráfica es un boxplot que muestra la distribución de las tarifas (fare) en función de la clase del pasajero (pclass).
#
# Se puede observar que los pasajeros de primera clase pagaron tarifas significativamente más altas en comparación con los de segunda y tercera clase.
# La mediana de la tarifa es más alta en primera clase, y hay una mayor dispersión de valores, lo que sugiere que algunos pasajeros pagaron tarifas extremadamente altas.
# En tercera clase, las tarifas son mucho más bajas y hay menos variabilidad en los precios.
# En conclusión, la clase del pasajero tenía una gran influencia en el costo del boleto, con precios más elevados para los pasajeros de mayor estatus.
# # ¿Qué problema encontramos con la segunda?
# La segunda gráfica es un swarmplot, que muestra la relación entre la tarifa y la supervivencia. Sin embargo, hay un problema importante:
#
# Superposición de puntos: Dado que los datos contienen muchas observaciones con valores similares, los puntos pueden amontonarse demasiado y hacer difícil distinguir patrones claros.
# Escalado de valores extremos: Como las tarifas varían en un rango amplio, algunos valores muy altos pueden hacer que los puntos más bajos sean menos visibles.
# Advertencia de Seaborn: A partir de versiones recientes, swarmplot puede generar advertencias cuando hay muchos puntos, lo que puede afectar el rendimiento.
# Posible solución: Se podría usar un violin plot o un jitter plot con sns.stripplot() para mejorar la visualización sin tanta superposición.
# # ¿Qué ciudad es más cara para adquirir el boleto?
# La tercera gráfica (ECDF) nos muestra la distribución proporcional de las tarifas en función del puerto de embarque (embark_town). Para determinar qué ciudad tenía los boletos más caros, podemos observar cuál tiene la mayor proporción de tarifas altas.
#
# Generalmente, en el dataset del Titanic:
#
# Cherburgo (C) tiende a tener las tarifas más altas, ya que muchos pasajeros de primera clase abordaron en este puerto.
# Southampton (S) tiene una distribución más equilibrada con muchas tarifas medias y bajas.
# Queenstown (Q) tiene las tarifas más bajas en general, con la mayoría de los pasajeros en tercera clase.
# Por lo tanto, Cherburgo es la ciudad más cara para adquirir el boleto.

# %% [markdown]
# # Apartado 11
#
# En este apartado, utilizaremos Seaborn para analizar la correlación entre los atributos numéricos del dataset Titanic mediante un heatmap (mapa de calor).
#
#     Visualización: Crearemos un heatmap con sns.heatmap, donde:
#
# Se calculará la matriz de correlación entre los atributos numéricos: corr_matrix = df.corr(numeric_only=True)
#
# Se aplicará un mapa de colores para facilitar la interpretación.
#
# Se mostrarán los valores dentro de las celdas para una mejor lectura.

# %%
# Apartado 11: Análisis de la correlación entre atributos numéricos en el Titanic
import seaborn as sns
import matplotlib.pyplot as plt

try:
    titanic_df = sns.load_dataset('titanic')

    # Calcular la matriz de correlación solo con valores numéricos
    corr_matrix = titanic_df.corr(numeric_only=True)

    # Crear el heatmap con anotaciones y un mapa de colores adecuado
    plt.figure(figsize=(10, 6))
    sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

    # Título del gráfico
    plt.title("Mapa de Calor de Correlación - Titanic")
    plt.show()

except Exception as e:
    print(f"Error en el análisis de correlación: {e}")

# %% [markdown]
# # ¿Qué variable parece más importante a la hora de predecir si sobrevivió el pasajero o no?
# La variable más importante para predecir la supervivencia parece ser el género (sex), seguido de la clase del pasajero (pclass) y la tarifa pagada (fare). Esto sugiere que ser mujer, viajar en primera clase y pagar un boleto más caro aumentaban significativamente las probabilidades de sobrevivir. 🚢💡

# %% [markdown]
# # Apartado 12
#
# En este apartado, utilizaremos Seaborn para analizar cómo la tasa de supervivencia varía en función del género y la clase del pasajero en el Titanic.
#
#     Visualización: Crearemos un gráfico de barras (barplot) con sns.barplot, donde:
#
# El eje X representará el género (sex).
#
# El eje Y mostrará la tasa de supervivencia (survived).
#
# Se usará hue para diferenciar la clase del pasajero (pclass).
#
# Se comparará la supervivencia entre diferentes grupos.
#
#     Este gráfico nos permitirá observar diferencias clave en la tasa de supervivencia según el género y la clase del pasajero, revelando tendencias en los datos.

# %%
try:
    titanic_df = sns.load_dataset('titanic')

    # Crear el gráfico de barras con diferenciación por clase
    plt.figure(figsize=(8, 6))
    sns.barplot(data=titanic_df, x='sex', y='survived', hue='pclass', palette='Set2')

    # Etiquetas y título
    plt.xlabel("Género")
    plt.ylabel("Tasa de Supervivencia")
    plt.title("Supervivencia en el Titanic según Género y Clase")
    plt.legend(title="Clase del Pasajero")

    # Mostrar el gráfico
    plt.show()

except Exception as e:
    print(f"Error en el análisis de supervivencia: {e}")

# %% [markdown]
# # Apartado 13
#
# En este apartado, utilizaremos Seaborn para analizar la distribución de edades de los pasajeros del Titanic en función de la clase en la que viajaban y su supervivencia.
#
#     Visualización: Crearemos un gráfico de violín (violinplot) con sns.violinplot, donde:
#
# Eje X: Representará la clase del pasajero (pclass).
#
# Eje Y: Mostrará la edad (age) de los pasajeros.
#
# Se diferenciará la supervivencia (survived) con hue y se activará split=True para visualizar ambas distribuciones dentro de cada clase.
#
# Se aplicará una suavización (bw) para mejorar la representación de la distribución de datos.
#
# Este gráfico nos ayudará a observar las diferencias en la edad de los pasajeros según su clase y su probabilidad de supervivencia.

# %%
try:
    # 
    titanic_df = sns.load_dataset('titanic')

    #
    plt.figure(figsize=(10, 6))

    # 
    sns.violinplot(
        data=titanic_df, x='pclass', y='age', hue='survived', split=True, 
        palette={0: "#c971f5", 1: "#71f5b7"},
        bw=0.05
    )

    #
    plt.xlabel("Clase del Pasajero", fontsize=12)
    plt.ylabel("Edad del Pasajero", fontsize=12)
    plt.title("Distribución de Edad según Clase y Supervivencia en el Titanic", fontsize=14)
    plt.legend(title="Supervivencia", labels=["No sobrevivió", "Sobrevivió"], loc='upper right')

    # 
    plt.show()

except Exception as e:
    print(f"Error en el análisis de edad: {e}")
# Out:
# C:\Users\alexc\AppData\Local\Temp\ipykernel_15892\2324269358.py:9: FutureWarning:
#
#
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.05`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.

# %% [markdown]
# # Apartado 14
#
# En este apartado, utilizaremos Seaborn para analizar la relación entre la edad de los pasajeros, la tarifa que pagaron y la clase en la que viajaban, incorporando además el número de familiares a bordo (sibsp) como una variable adicional.
#
#     Visualización: Crearemos un gráfico conjunto (jointplot) con sns.jointplot, donde:
#
# Eje X: Representará la edad (age) del pasajero.
#
# Eje Y: Mostrará la tarifa (fare) que pagaron.
#
# Hue (pclass): Diferenciará a los pasajeros según su clase (1ª, 2ª y 3ª).
#
# Se visualizarán distribuciones marginales en los ejes X e Y.
#
# Este gráfico nos permitirá explorar la distribución de tarifas en función de la edad, clase y el número de familiares a bordo, para detectar posibles patrones de viaje en el Titanic.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el dataset Titanic
titanic_df = sns.load_dataset('titanic')

# Eliminar filas con valores nulos en las columnas relevantes
titanic_df = titanic_df.dropna(subset=['age', 'fare', 'pclass'])

# Crear el gráfico conjunto
g = sns.jointplot(
    data=titanic_df, x="age", y="fare", hue="pclass", 
    palette=["#d4a4a4", "#a48ca4", "#4a2c4a"],  # Colores más parecidos a la segunda imagen
    kind="scatter", alpha=0.6, marginal_kws={"common_norm": False}
)

# Ajustar los gráficos marginales para que coincidan con la segunda imagen
for pclass, color in zip([1, 2, 3], ["#d4a4a4", "#a48ca4", "#4a2c4a"]):
    subset = titanic_df[titanic_df["pclass"] == pclass]  # Filtrar por clase
    sns.kdeplot(data=subset, x="age", fill=True, ax=g.ax_marg_x, alpha=0.4, color=color)
    sns.kdeplot(data=subset, y="fare", fill=True, ax=g.ax_marg_y, alpha=0.4, color=color)

# Ajustes finales
g.ax_joint.set_xlim(-5, 85)  
g.ax_joint.set_ylim(-10, 600)  
g.ax_joint.set_xlabel("Edad", fontsize=12)
g.ax_joint.set_ylabel("Tarifa", fontsize=12)
g.figure.suptitle("Relación entre Edad, Tarifa y Clase en el Titanic", fontsize=14)

plt.show()

# %% [markdown]
# # Apartado 15
#
# Carga de datos: Importa el archivo CSV GlobalWeatherRepository.csv en un DataFrame de pandas.
#
#     Selección de datos: Filtra la información para mostrar únicamente las temperaturas de los siguientes países:
#
# España, Tailandia, Nueva Zelanda y Estados Unidos.
#
#     Visualización:
#
# Genera un gráfico de líneas con PLOTLY que muestre la evolución de la temperatura media a lo largo del año para estos cuatro países.
#
# Los marcadores tendrán que mostrar la temperatura (el número) y ser redondos.

# %%
import pandas as pd
import plotly.express as px
from plotly.offline import init_notebook_mode

# Habilitar renderizado interactivo en Jupyter
init_notebook_mode(connected=True)

# Cargar los datos desde el archivo CSV
archivo_csv = "GlobalWeatherRepository.csv"
df = pd.read_csv(archivo_csv)

# Convertir la columna "last_updated" a tipo datetime
df["last_updated"] = pd.to_datetime(df["last_updated"])

# Filtrar solo los países deseados
paises_interes = ["Spain", "Thailand", "New Zealand", "United States of America"]
df_filtrado = df[df["country"].isin(paises_interes)]

# Agrupar por país y fecha (cada día), luego calcular la temperatura media
df_grouped = df_filtrado.groupby(["country", "last_updated"])["temperature_celsius"].mean().reset_index()

# Crear el gráfico de líneas interactivo con Plotly
fig = px.line(
    df_grouped, 
    x="last_updated", 
    y="temperature_celsius", 
    color="country", 
    markers=True, 
    text="temperature_celsius", 
    title="Temperatura Media Diaria por País",
    labels={"temperature_celsius": "Temperatura Media (°C)", "last_updated": "Fecha", "country": "País"}
)

# Ajustar la posición del texto para que quede un poco más arriba
fig.update_traces(
    textposition="top center",  # Mantenerlo arriba del punto
    mode="lines+markers+text",  # Mostrar líneas, puntos y texto
)

# Personalización del gráfico (ejes y leyenda)
fig.update_layout(
    xaxis_title="Fecha", 
    yaxis_title="Temperatura Media (°C)", 
    legend_title="País"
)

# Mostrar el gráfico
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="18c6f454-1dc8-4b82-8864-f690a5dba326" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("18c6f454-1dc8-4b82-8864-f690a5dba326")) {                    Plotly.newPlot(                        "18c6f454-1dc8-4b82-8864-f690a5dba326",                        [{"hovertemplate":"Pa\u00eds=New Zealand\u003cbr\u003eFecha=%{x}\u003cbr\u003eTemperatura Media (\u00b0C)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"New Zealand","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"New Zealand","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAIkAAAAAAAAAqQAAAAAAAACxAAAAAAAAALEAAAAAAAAAwQAAAAAAAACxAAAAAAAAAKkAAAAAAAAAsQAAAAAAAACxAAAAAAAAAMEAAAAAAAAAuQAAAAAAAAC5AAAAAAAAALkAAAAAAAAAuQAAAAAAAACxAAAAAAAAALkA="},"x":["2023-08-29T21:30:00.000000000","2023-08-30T15:00:00.000000000","2023-08-31T11:45:00.000000000","2023-09-01T11:45:00.000000000","2023-09-02T11:30:00.000000000","2023-09-03T11:45:00.000000000","2023-09-04T11:30:00.000000000","2023-09-05T11:30:00.000000000","2023-09-06T11:15:00.000000000","2023-09-07T11:00:00.000000000","2023-09-08T11:00:00.000000000","2023-09-09T10:45:00.000000000","2023-09-10T10:45:00.000000000","2023-09-11T11:00:00.000000000","2023-09-12T11:00:00.000000000","2023-09-13T10:45:00.000000000"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAIkAAAAAAAAAqQAAAAAAAACxAAAAAAAAALEAAAAAAAAAwQAAAAAAAACxAAAAAAAAAKkAAAAAAAAAsQAAAAAAAACxAAAAAAAAAMEAAAAAAAAAuQAAAAAAAAC5AAAAAAAAALkAAAAAAAAAuQAAAAAAAACxAAAAAAAAALkA="},"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Pa\u00eds=Spain\u003cbr\u003eFecha=%{x}\u003cbr\u003eTemperatura Media (\u00b0C)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Spain","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"Spain","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAANEAAAAAAAAAyQAAAAAAAADVAAAAAAAAANkAAAAAAAAA3QAAAAAAAADBAAAAAAAAAMUAAAAAAAAAzQAAAAAAAADVAAAAAAAAAN0AAAAAAAAA4QAAAAAAAADdAAAAAAAAAM0AAAAAAAAA0QAAAAAAAADNAAAAAAAAANEA="},"x":["2023-08-29T11:45:00.000000000","2023-08-30T05:00:00.000000000","2023-08-31T01:45:00.000000000","2023-09-01T01:45:00.000000000","2023-09-02T01:30:00.000000000","2023-09-03T01:45:00.000000000","2023-09-04T01:45:00.000000000","2023-09-05T01:30:00.000000000","2023-09-06T01:15:00.000000000","2023-09-07T01:00:00.000000000","2023-09-08T01:00:00.000000000","2023-09-09T01:00:00.000000000","2023-09-10T01:00:00.000000000","2023-09-11T00:45:00.000000000","2023-09-12T01:00:00.000000000","2023-09-13T00:45:00.000000000"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAANEAAAAAAAAAyQAAAAAAAADVAAAAAAAAANkAAAAAAAAA3QAAAAAAAADBAAAAAAAAAMUAAAAAAAAAzQAAAAAAAADVAAAAAAAAAN0AAAAAAAAA4QAAAAAAAADdAAAAAAAAAM0AAAAAAAAA0QAAAAAAAADNAAAAAAAAANEA="},"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Pa\u00eds=Thailand\u003cbr\u003eFecha=%{x}\u003cbr\u003eTemperatura Media (\u00b0C)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thailand","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"Thailand","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAACAQEAAAAAAAIA8QAAAAAAAADpAAAAAAACAOUAAAAAAAAA6QAAAAAAAADxAAAAAAACAOUAAAAAAAAA6QAAAAAAAgDpAAAAAAAAAOkAAAAAAAIA6QAAAAAAAgDpAAAAAAAAAOUAAAAAAAAA8QAAAAAAAADlAAAAAAAAAOkAAAAAAAIA4QAAAAAAAADpAAAAAAAAAOkA="},"x":["2023-08-29T16:45:00.000000000","2023-08-30T10:00:00.000000000","2023-08-31T06:45:00.000000000","2023-09-01T06:45:00.000000000","2023-09-02T06:30:00.000000000","2023-09-02T06:45:00.000000000","2023-09-03T06:45:00.000000000","2023-09-04T06:30: ...

# %% [markdown]
# # Apartado 16
#
# El objetivo de este apartado es analizar la relación entre la temperatura y la humedad en diferentes países, utilizando un gráfico de dispersión interactivo con Plotly. Además, se representará la velocidad del viento mediante el tamaño de los puntos en el gráfico.
#
#     Selección de datos:
# Filtra la información de los siguientes países:
#
# España
# Tailandia
# Nueva Zelanda
# Estados Unidos
#
#     Creación de la visualización:
#
# Usa Plotly para generar un gráfico de dispersión (scatter plot) donde:
#
# Eje X: Temperatura (°C)
#
# Eje Y: Humedad (%)
#
# Tamaño de los puntos: Velocidad del viento (km/h)
#
# Color de los puntos: Temperatura (°C), utilizando la escala de colores "tempo"
#
# Agrega información adicional en el hover para mostrar el nombre del país y la ciudad.

# %%
import pandas as pd
import plotly.express as px
from plotly.offline import init_notebook_mode

# Habilitar renderizado interactivo en Jupyter
init_notebook_mode(connected=True)

# Cargar los datos desde el archivo CSV
archivo_csv = "GlobalWeatherRepository.csv"
df = pd.read_csv(archivo_csv)

# Filtrar solo los países deseados
paises_interes = ["Spain", "Thailand", "New Zealand", "United States of America"]
df_filtrado = df[df["country"].isin(paises_interes)]

# Crear el gráfico de dispersión
fig = px.scatter(
    df_filtrado, 
    x="temperature_celsius", 
    y="humidity", 
    size="wind_kph",  # Tamaño de los puntos según la velocidad del viento
    color="temperature_celsius",  # Color según la temperatura
    color_continuous_scale="tempo",  # Escala de colores
    hover_data={"country": True, "location_name": True, "wind_kph": True},  # Mostrar país, ciudad y viento en hover
    title="Relación entre Temperatura y Humedad con Velocidad del Viento",
    labels={
        "temperature_celsius": "Temperatura (°C)", 
        "humidity": "Humedad (%)", 
        "wind_kph": "Velocidad del Viento (km/h)", 
        "country": "País", 
        "location_name": "Ubicación"
    }
)

# Mejorar el diseño del gráfico
fig.update_layout(
    xaxis_title="Temperatura (°C)", 
    yaxis_title="Humedad (%)", 
    coloraxis_colorbar_title="Temperatura (°C)"
)

# Mostrar el gráfico
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="7921df7e-b92c-414c-97ee-6c7d1fcebd20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7921df7e-b92c-414c-97ee-6c7d1fcebd20")) {                    Plotly.newPlot(                        "7921df7e-b92c-414c-97ee-6c7d1fcebd20",                        [{"customdata":[["Thailand","Nan",3.6],["New Zealand","Wellington",19.1],["Spain","Madrid",6.1],["Thailand","Bangkok",11.2],["United States of America","Washington Park",15.1],["Thailand","Nan",3.6],["New Zealand","Wellington",33.1],["Spain","Madrid",6.8],["Thailand","Bangkok",6.8],["United States of America","Washington Park",11.2],["Thailand","Nan",4.0],["New Zealand","Wellington",37.1],["Spain","Madrid",3.6],["Thailand","Bangkok",6.1],["United States of America","Washington Park",24.1],["Thailand","Nan",3.6],["New Zealand","Wellington",37.1],["Spain","Madrid",3.6],["Thailand","Bangkok",9.0],["United States of America","Washington Park",15.1],["Thailand","Nan",6.8],["New Zealand","Wellington",4.0],["Spain","Madrid",3.6],["Thailand","Bangkok",9.0],["United States of America","Washington Park",9.0],["Thailand","Nan",4.0],["New Zealand","Wellington",11.2],["Spain","Madrid",6.1],["Thailand","Bangkok",13.0],["United States of America","Washington Park",16.9],["Thailand","Nan",3.6],["New Zealand","Wellington",19.1],["Spain","Madrid",3.6],["Thailand","Bangkok",3.6],["United States of America","Washington Park",3.6],["Thailand","Nan",3.6],["New Zealand","Wellington",6.1],["Spain","Madrid",6.8],["Thailand","Bangkok",11.2],["United States of America","Washington Park",20.2],["Thailand","Nan",3.6],["New Zealand","Wellington",37.1],["Spain","Madrid",6.1],["Thailand","Bangkok",6.8],["United States of America","Washington Park",9.0],["Thailand","Nan",3.6],["New Zealand","Wellington",22.0],["Spain","Madrid",6.1],["Thailand","Bangkok",6.8],["United States of America","Washington Park",11.2],["Thailand","Nan",3.6],["New Zealand","Wellington",11.2],["Spain","Madrid",6.1],["Thailand","Bangkok",6.8],["United States of America","Washington Park",11.2],["Thailand","Nan",3.6],["New Zealand","Wellington",11.2],["Spain","Madrid",6.1],["Thailand","Bangkok",13.0],["United States of America","Washington Park",6.8],["Thailand","Nan",9.0],["New Zealand","Wellington",25.9],["Spain","Madrid",9.0],["Thailand","Bangkok",6.1],["United States of America","Washington Park",9.0],["Thailand","Nan",6.1],["New Zealand","Wellington",41.0],["Spain","Madrid",6.1],["Thailand","Bangkok",6.8],["United States of America","Washington Park",3.6],["Thailand","Nan",3.6],["New Zealand","Wellington",25.9],["Spain","Madrid",4.0],["Thailand","Bangkok",4.0],["United States of America","Washington Park",3.6],["Thailand","Nan",3.6],["New Zealand","Wellington",19.1],["Spain","Madrid",6.8],["Thailand","Bangkok",6.1],["United States of America","Washington Park",3.6]],"hovertemplate":"Temperatura (\u00b0C)=%{marker.color}\u003cbr\u003eHumedad (%)=%{y}\u003cbr\u003eVelocidad del Viento (km\u002fh)=%{customdata[2]}\u003cbr\u003ePa\u00eds=%{customdata[0]}\u003cbr\u003eUbicaci\u00f3n=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"..."},"coloraxis":"coloraxis","size":{"dtype":"f8","bdata":"..."},"sizemode":"area","sizeref":0.1025,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"..."},"xaxis":"x","y":{"dtype":"i1","bdata":"P1ExOC1eSC1HKGRIKF4cZD8hWUFePy9KKmRDWEodZE1eVCFkP1hKHl5YRVQeZD9BRhReSD1UHmRDRUYbXkhYXhlkSFNeFF43RFQaXiw8Txk="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111 ...

# %% [markdown]
# # Apartado 17
#
# El objetivo de este ejercicio es visualizar la distribución de la temperatura y la humedad en diferentes países mediante un mapa interactivo con Plotly. Utilizaremos coordenadas geográficas (latitud y longitud) para representar los puntos en el mapa y analizaremos las variaciones climáticas en distintas ubicaciones.
#
#     Selección de datos: Todos los paises (df)
#
# Creación del mapa interactivo:
#
#     Usa Plotly para generar un mapa interactivo donde:
#
# Ubicación de los puntos: Coordenadas geográficas (latitud y longitud).
#
# Color de los puntos: Representa la temperatura en grados Celsius (°C), utilizando la escala de colores
# IceFire.
#
# Tamaño de los puntos: Basado en el porcentaje de humedad.
#
# Información adicional en hover: Muestra el nombre de la ciudad.
#
# Ajusta la visualización para que el mapa tenga un estilo OpenStreetMap, con un nivel de zoom adecuado.

# %%
# Habilitar renderizado interactivo en Jupyter
init_notebook_mode(connected=True)

# Cargar los datos desde el archivo CSV
archivo_csv = "GlobalWeatherRepository.csv"
df = pd.read_csv(archivo_csv)

# Crear el mapa interactivo con coordenadas geográficas
fig = px.scatter_mapbox(
    df,
    lat="latitude",
    lon="longitude",
    size="humidity",  # Tamaño del punto según la humedad
    size_max=8,  # Reducir el tamaño máximo de los puntos
    color="temperature_celsius",  # Color según la temperatura
    color_continuous_scale="icefire",  # Escala de colores para la temperatura
    hover_data={"location_name": True},  # Mostrar el nombre de la ciudad en el hover
    title="Distribución de Temperatura y Humedad en el Mundo"
)

# Configurar el estilo del mapa y nivel de zoom
fig.update_layout(
    mapbox_style="open-street-map",  # Estilo OpenStreetMap
    mapbox_zoom=2.0,  # Nivel de zoom inicial
    mapbox_center={"lat": 20, "lon": 0},  # Centrar el mapa en una latitud y longitud general
    margin={"r": 0, "t": 50, "l": 0, "b": 0}  # Ajustar los márgenes
)

# Mostrar el mapa
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>
# C:\Users\alexc\AppData\Local\Temp\ipykernel_15892\2073356249.py:9: DeprecationWarning:
#
# *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="168c3e08-c2d5-4c97-a306-6393c73ca8a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("168c3e08-c2d5-4c97-a306-6393c73ca8a4")) {                    Plotly.newPlot(                        "168c3e08-c2d5-4c97-a306-6393c73ca8a4",                        [{"customdata":[["Kabul"],["Tirana"],["Algiers"],["Andorra La Vella"],["Luanda"],["Saint John's"],["Buenos Aires"],["Yerevan"],["Canberra"],["Vienna"],["Baku"],["Nassau"],["Manama"],["Dhaka"],["Bridgetown"],["Minsk"],["Brussels"],["Belmopan"],["Porto-Novo"],["Thimphu"],["Sucre"],["Sarajevo"],["Gaborone"],["Bras"],["Bandar Seri Begawan"],["Sofia"],["Ouagadougou"],["Bujumbura"],["Ivory"],["Praia"],["Phnom Penh"],["Bafoussam"],["Ottawa"],["Bangui"],["N'djamena"],["Santiago"],["Beijing"],["Bogot"],["Moroni"],["Brazzaville"],["San Juan"],["Zagreb"],["Havana"],["Nicosia"],["Prague"],["Kinshasa"],["Copenhagen"],["Djibouti"],["Roseau"],["Santo Domingo"],["Quito"],["Cairo"],["San Salvador"],["Malabo"],["Asmara"],["Tallinn"],["Mbabane"],["Addis Ababa"],["Suva"],["Helsinki"],["Paris"],["Libreville"],["Banjul"],["Tbilisi"],["Berlin"],["Accra"],["Athens"],["Saint George's"],["Guatemala City"],["Conakry"],["Bissau"],["Georgetown"],["Port-Au-Prince"],["Vatican City"],["Tegucigalpa"],["Budapest"],["Hella"],["New Delhi"],["Jakarta"],["Tehran"],["Baghdad"],["Dublin"],["Jerusalem"],["Rome"],["Norman Gardens"],["Tokyo"],["Amman"],["Astana"],["Nairobi"],["Tarawa"],["Kuwait City"],["Bishkek"],["Laos"],["Riga"],["Beirut"],["Maseru"],["Monrovia"],["Nan"],["Vaduz"],["Vilnius"],["Luxembourg"],["Antananarivo"],["Lilongwe"],["Kuala Lumpur"],["Farukolhufunadhoo"],["Bamako"],["Valletta"],["Majuro"],["Nouakchott"],["Port Louis"],["Mexico City"],["Palikir"],["Chi-Chi-Erh"],["Monaco"],["Ulaanbaatar"],["Podgorica"],["Rabat"],["Maputo"],["Pathein"],["Windhoek"],["Yaren"],["Kathmandu"],["Amsterdam"],["Wellington"],["Managua"],["Niamey"],["Abuja"],["Pyongyang"],["Skopje"],["Oslo"],["Muscat"],["Islamabad"],["Adkip"],["National"],["Panama City"],["Port Moresby"],["Carreria"],["Lima"],["Manila"],["Warsaw"],["Lisbon"],["Doha"],["Bucharest"],["Moscow"],["Kigali"],["Basseterre"],["Castries"],["Kingstown"],["Apia"],["San Marino"],["'S-Gravenwezel"],["Riyadh"],["Dakar"],["Belgrade"],["Victoria"],["Freetown"],["Singapore"],["Bratislava"],["Ljubljana"],["Honiara"],["Mogadishu"],["Pretoria"],["Seoul"],["Juba"],["Madrid"],["Colombo"],["Khartoum"],["Paramaribo"],["Stockholm"],["Bern"],["Damascus"],["Dushanbe"],["Dodoma"],["Bangkok"],["Murong Timor"],["Lom"],["Nuku`Aloia"],["Port Of Spain"],["Tunis"],["Ankara"],["Ashgabat"],["Funafuti"],["Kampala"],["Lviv"],["Abu Dhabi"],["London"],["Washington Park"],["Montevideo"],["Tashkent"],["Port Vila"],["Caracas"],["Hanoi"],["Sanaa"],["Lusaka"],["Harare"],["Kabul"],["Tirana"],["Algiers"],["Andorra La Vella"],["Luanda"],["Saint John's"],["Buenos Aires"],["Yerevan"],["Canberra"],["Vienna"],["Baku"],["Nassau"],["Manama"],["Dhaka"],["Bridgetown"],["Minsk"],["Brussels"],["Belmopan"],["Porto-Novo"],["Thimphu"],["Sucre"],["Sarajevo"],["Gaborone"],["Bras"],["Bandar Seri Begawan"],["Sofia"],["Ouagadougou"],["Bujumbura"],["Ivory"],["Praia"],["Phnom Penh"],["Bafoussam"],["Ottawa"],["Bangui"],["N'djamena"],["Santiago"],["Beijing"],["Bogot"],["Moroni"],["Brazzaville"],["San Juan"],["Zagreb"],["Havana"],["Nicosia"],["Prague"],["Kinshasa"],["Copenhagen"],["Djibouti"],["Roseau"],["Santo Domingo"],["Quito"],["Cairo"],["San Salvador"],["Malabo"],["Asmara"],["Tallinn"],["Mbabane"],["Addis Ababa"],["Suva"],["Helsinki"],["Paris"],["Libreville"],["Banjul"],["Tbilisi"],["Berlin"],["Accra"],["Athens"],["Saint George's"],["Guatemala City"],["Conakry"],["Bissau"],["Georgetown"],["Port-Au-Prince"],["Vatican City"],["Tegucigalpa"],["Bud ...

# %% [markdown]
# # Apartado 18 (1.5 puntos)
#
# El objetivo de este apartado es crear un dashboard interactivo (Plotly) para visualizar datos relacionados con las temperaturas globales, utilizando "TemperaturasGlobales.csv".
#
#     Carga el dataset
#
#     fig1) Muestra un gráfico de líneas con la evolución de la temperatura media global
#
#     fig2) Muestra un gráfico de barras con los 10 países con mayor variación de temperatura: df_top10 = df.nlargest(10, 'Temperature Variation')
#
#
#     fig3) Muestra un mapa 3D con la variación de temperatura en 2021 de todos los países (solo valores positivos)
# df_2021 = df_2021[df_2021["Temperature 2021"] > 0].
#
# Todas las figuras usarán el template:     template="plotly_dark",
#
#
#     Integra todas las figuras en un dashboad con la librería DASH: from dash import Dash, dcc, html. En la primera fila se encontrará sólo el mapa del mundo y en la segunda ambas gráficas.
#
#
#     Personaliza el dashboard para que:
#
# Tenga el fondo nde color #111111
#
# Tenga el grid y las letras de color blanco
#
# Tenga los gráficos y la representación de temperaturas en tonos rojos
#
# Añade titulos al dashboad, sus gráficas y ejes.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html

# Cargar los datos
archivo_csv = "TemperaturasGlobales.csv"
df = pd.read_csv(archivo_csv)

# 1) Gráfico de líneas: Evolución de la temperatura media global por año
# Seleccionar las columnas de los años
years = [str(year) for year in range(1970, 2022)]
df_temp_global = df[years].mean(axis=0).reset_index()
df_temp_global.columns = ["Año", "Temperatura Media Global (°C)"]

# Crear el gráfico de líneas
fig1 = px.line(
    df_temp_global,
    x="Año",
    y="Temperatura Media Global (°C)",
    title="Evolución de la Temperatura Media Global por Año",
    labels={"Año": "Año", "Temperatura Media Global (°C)": "Temperatura Media Global (°C)"},
    template="plotly_dark",
    line_shape="spline"
)

# Personalizar color de la línea
fig1.update_traces(line=dict(color="red"))

# 2) Gráfico de barras: Top 10 países con mayor cambio de temperatura
# Calcular el cambio de temperatura como la diferencia entre el valor máximo y mínimo por país
df['Temperature Change'] = df[years].max(axis=1) - df[years].min(axis=1)

# Seleccionar los 10 países con mayor cambio de temperatura
df_top10 = df[['Country Name', 'Temperature Change']].nlargest(10, 'Temperature Change')

# Crear el gráfico de barras
fig2 = px.bar(
    df_top10,
    x="Country Name",
    y="Temperature Change",
    title="Top 10 Países con Mayor Cambio de Temperatura",
    labels={"Country Name": "País", "Temperature Change": "Cambio de Temperatura (°C)"},
    template="plotly_dark",
    color="Temperature Change",
    color_continuous_scale="reds"
)

# 3) Mapa en forma de globo con la variación de temperatura en 2021 (solo positivos)
# Calcular la variación de temperatura en 2021 (solo valores positivos)
df['Temperature Change 2021'] = df['2021'] - df['1970']

# Filtrar para considerar solo los valores positivos
df_2021_positive = df[df['Temperature Change 2021'] > 0]

# Crear el gráfico del mapa
fig3 = px.choropleth(
    df_2021_positive,
    locations="Country Name",
    locationmode="country names",
    color="Temperature Change 2021",
    hover_name="Country Name",
    title="Variación de Temperatura en 2021 (Solo Valores Positivos)",
    template="plotly_dark",
    color_continuous_scale="reds",
    projection="orthographic"  # Proyección en forma de globo
)

# Crear la app de Dash
app = Dash(__name__)

app.layout = html.Div(style={'backgroundColor': '#111111', 'color': 'white', 'padding': '20px'}, children=[

    html.H1("Dashboard de Evolución de Temperaturas Globales", style={'textAlign': 'center'}),

    # Primera fila: Mapa de variación de temperatura en 2021 (solo positivos)
    html.Div(children=[dcc.Graph(figure=fig3)]),

    # Segunda fila: Gráfico de líneas y barras
    html.Div(style={'display': 'flex', 'justify-content': 'space-around'}, children=[
        dcc.Graph(figure=fig1, style={'width': '48%'}),
        dcc.Graph(figure=fig2, style={'width': '48%'})
    ])
])

# Ejecutar el servidor
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
